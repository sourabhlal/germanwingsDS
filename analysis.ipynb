# %%
import pandas as pd

# %%
pd.read_pickle('cleanData.pkl')
# Out:
#      Cabin Flown      Date Flown Recommended score  \
# 0        Economy    October 2015          no     2
# 1        Economy    October 2015          no     3
# 2        Economy  September 2015          no     3
# 3            NaN  September 2015         yes    10
# 4        Economy  September 2015          no     4
# 5        Economy  September 2015          no     1
# 6        Economy  September 2015         yes     7
# 7        Economy  September 2015          no     2
# 8        Economy     August 2015          no     2
# 9        Economy     August 2015          no     5
# 10       Economy     August 2015          no     2
# 11       Economy       July 2015         yes    10
# 12   First Class       July 2015          no     1
# 13       Economy       June 2015          no     2
# 14       Economy        May 2015         yes     7
# 15       Economy        May 2015         yes     7
# 16       Economy        May 2015         yes     9
# ...
